# %% [markdown]
# # Read Data

# %%
from tqdm.notebook import trange
import numpy as np

# %%
N = 500000
pt0 = np.fromfile("../../Downloads/fame_coaes/pt_500k_600_4mhz.bin", dtype=np.uint8)
text_arrays = np.array_split(pt0,N)
print(len(text_arrays[N-1]))
print(len(text_arrays))
# Out:
# 16
# 500000

# %%
t0 = np.array_split(np.fromfile("../../Downloads/fame_coaes/t_500k_600_4mhz.bin", dtype=np.float64),N)
#print(t0[0])
print(len(t0[N-1]))
print(len(t0))
# Out:
# 600
# 500000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure()
for i in range (2):
    plt.plot(t0[i])
plt.show()

# %%
traces_enc = []
for i in range (len(t0)):
    traces_enc.append(t0[i][0:600])

# %%
print(len(traces_enc[0]))
print(len(traces_enc))
# Out:
# 600
# 500000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure()
for i in range (2):
    plt.plot(traces_enc[i])
plt.show()

# %%
traces_enc = np.array(traces_enc)

# %%
guess_full = []
for i in range (16):
    guess = []
    for j in range (256):
        a = [j]
        b = np.pad(a, (i,15-i), 'constant', constant_values=(0,0))
        guess.append(b)
    guess_full.append(guess)

# %%
# %cd /home/zliu12/chipwhisperer-tvla
import numpy as np
from tqdm.notebook import trange
from cwtvla.ktp import calc_AES_state

pt_array = text_arrays

bnum = 0

bnum_list_full = []
for guess in trange (0,256):
    bnum_list = []
    for textin in trange (len(pt_array)):
        state = np.array(calc_AES_state(pt_array[textin], guess_full[bnum][guess]))
        bnum_list.append(state[0])
    bnum_list_full.append(bnum_list)
# Out:
# /home/zliu12/chipwhisperer-tvla
# ...
#   0%|          | 0/500000 [00:00<?, ?it/s]

# %%
np.array(bnum_list_full).tofile("bnum_0_list_full.bin")

# %%
sbox = (
    )

def intermediate(pt, keyguess):
    return sbox[pt ^ keyguess]

HW = [bin(n).count("1") for n in range(0, 256)]

# %%
numtraces = len(traces_enc) #total number of traces
numpoint = len(traces_enc[0]) #samples per trace

key_guess = []
full_cpa_list = []
known_key = [0x54, 0xee, 0xff, 0x11, 0x21, 0x32, 0xeb, 0x43, 0xbb, 0xaa, 0xff, 0x23, 0x98, 0x54, 0x12, 0x12]

# %%
for bnum in trange(0, 16):
    cpaoutput = [0] * 256
    maxcpa = [0] * 256
    for kguess in trange(0, 256):

        # Initialize arrays &amp; variables to zero
        sumnum = np.zeros(numpoint)
        sumden1 = np.zeros(numpoint)
        sumden2 = np.zeros(numpoint)
        
        hyp = np.zeros(numtraces)
        for tnum in range(0, numtraces):
            st1 = text_arrays[tnum][bnum] ^ kguess
            st2 = bnum_list_full[kguess][tnum]
            hyp[tnum] = HW[st1 ^ st2]

        # Mean of hypothesis
        meanh = np.mean(hyp, dtype=np.float64)

        # Mean of all points in trace
        meant = np.mean(traces_enc, axis=0, dtype=np.float64)

        # For each trace, do the following
        for tnum in range(0, numtraces):
            hdiff = (hyp[tnum] - meanh)
            tdiff = traces_enc[tnum, :] - meant

            sumnum = sumnum + (hdiff * tdiff)
            sumden1 = sumden1 + hdiff * hdiff
            sumden2 = sumden2 + tdiff * tdiff

        cpaoutput[kguess] = sumnum / np.sqrt(sumden1 * sumden2)
        maxcpa[kguess] = max(abs(cpaoutput[kguess]))

    full_cpa_list.append(cpaoutput)
    #np.array(full_cpa_list[bnum]).tofile("new_cpa_byte%2d.bin" %(bnum))
    sorted_args = np.argsort(maxcpa)[::-1]
    key_guess.append(sorted_args[0])
    print("Subkey %2d - most likely %02X (actual %02X)"%(bnum, key_guess[bnum], known_key[bnum]))
    print(" Top 5 guesses: ")
    for i in range(0, 10):
        g = sorted_args[i]
        print("   %02X - Diff = %f"%(g, maxcpa[g]))
    print("\n")
        
    plt.figure()
    for guess in range(0, 256):
        if (guess == known_key[bnum]):
            plt.plot(abs(full_cpa_list[bnum][guess]),color="red",linewidth=1.5, linestyle='-',zorder=255)
        else:
            plt.plot(abs(full_cpa_list[bnum][guess]),color="grey")
    plt.show()
# Out:
# ...
#   0%|          | 0/256 [00:00<?, ?it/s]
# Subkey  0 - most likely 23 (actual 54)
#  Top 5 guesses:
#    23 - Diff = 0.006058
#    6F - Diff = 0.006051
#    C5 - Diff = 0.005911
#    C2 - Diff = 0.005773
#    F9 - Diff = 0.005672
#    82 - Diff = 0.005670
#    97 - Diff = 0.005625
#    33 - Diff = 0.005593
#    26 - Diff = 0.005550
#    B8 - Diff = 0.005515
#   0%|          | 0/256 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-8504cba64bfb> in <module>
#      26             tdiff = traces_enc[tnum, :] - meant
#      27
# ---> 28             sumnum = sumnum + (hdiff * tdiff)
#      29             sumden1 = sumden1 + hdiff * hdiff
#      30             sumden2 = sumden2 + tdiff * tdiff
#
# KeyboardInterrupt:

# %%
import pylab
plt.figure()
f, axs = plt.subplots(4,4,figsize=(25,25))
value = 1
for subkey in range (16):
    pylab.subplot(4,4,value)
    for guess in range(0, 256):
        if (guess == known_key[subkey]):
            plt.plot(abs(full_cpa_list[subkey][guess]),color="red",linewidth=1.5, linestyle='-',zorder=255)
        else:
            plt.plot(abs(full_cpa_list[subkey][guess]),color="grey")
    value += 1
    corr = abs(full_cpa_list[subkey][known_key[subkey]])
    xmax = np.argmax(corr)
    ymax = corr.max()
    plt.plot([xmax],[ymax],marker='.', markersize=20, color="red",zorder=255)
    plt.title('Subkey %2d, Correlation %2f at sample point %d' %(subkey-1,ymax,xmax))
    
plt.tight_layout()
plt.subplots_adjust(top=0.95)

#################################edit the title and figure name###########################3
plt.suptitle('COAES FAME CPA Correltaion vs. Samples', size=30)

plt.show()
