# %% [markdown]
# # Plot Trace_enc

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure()
plt.plot(traces_enc[0])
plt.show()

# %% [markdown]
# # Plot 16 Key Bytes

# %% [markdown]
# ### Byte 0

# %%
correct_key = 84 # 0x54
subkey = 0
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
max(full_diffs_list[0][0x54])
# Out:
# 0.009366775759896591

# %%
# %matplotlib inline
import matplotlib.pylab as plt

plt.plot(full_diffs_list[0][0x5B], 'grey')
plt.plot(full_diffs_list[0][0x59], 'grey')
plt.plot(full_diffs_list[0][0xDE], 'grey')
plt.plot(full_diffs_list[0][0x58], 'grey')
plt.plot(full_diffs_list[0][0xDA], 'grey')
plt.plot(full_diffs_list[0][0x54], 'red')

# %%
# %matplotlib inline
import matplotlib.pylab as plt

plt.plot(full_diffs_list[0][0x5B], 'grey')
plt.plot(full_diffs_list[0][0x59], 'grey')
plt.plot(full_diffs_list[0][0xDE], 'grey')
plt.plot(full_diffs_list[0][0x58], 'grey')
plt.plot(full_diffs_list[0][0xDA], 'grey')
plt.plot(full_diffs_list[0][0x54], 'red')
plt.xlim([5250, 5600])
# Out:
# (5250.0, 5600.0)

# %% [markdown]
# ### Byte 1

# %%
correct_key = 238 #0xee
subkey = 1
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 238 #0xee
subkey = 1
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([6500, 6700])
plt.show()

# %% [markdown]
# ### Byte 2

# %%
correct_key = 255 #0xff
subkey = 2
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 255 #0xff
subkey = 2
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([7700, 8000])
plt.show()

# %% [markdown]
# ### Byte 3

# %%
correct_key = 17 #0x11
subkey = 3
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 17 #0x11
subkey = 3
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([8900, 9200])
plt.show()

# %% [markdown]
# ### Byte 4

# %%
correct_key = 33 #0x21
subkey = 4
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 33 #0x21
subkey = 4
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([5500, 5700])
plt.show()

# %% [markdown]
# ### Byte 5

# %%
correct_key = 50 #0x32
subkey = 5
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 50 #0x32
subkey = 5
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([6700, 7000])
plt.show()

# %% [markdown]
# ### Byte 6

# %%
correct_key = 235 #0xeb
subkey = 6
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 235 #0xeb
subkey = 6
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([8000, 8300])
plt.show()

# %% [markdown]
# ### Byte 7

# %%
correct_key = 67 #0x43
subkey = 7
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 67 #0x43
subkey = 7
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([9200, 9400])
plt.show()

# %% [markdown]
# ### Byte 8

# %%
correct_key = 187 #0xbb
subkey = 8
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 187 #0xbb
subkey = 8
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([5800, 6000])
plt.show()

# %% [markdown]
# ### Byte 9

# %%
correct_key = 170 #0xaa
subkey = 9
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 170 #0xaa
subkey = 9
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([7050, 7300])
plt.show()

# %% [markdown]
# ### Byte 10

# %%
correct_key = 255 #0xff
subkey = 10
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 255 #0xff
subkey = 10
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([10200, 10550])
plt.show()

# %% [markdown]
# ### Byte 11

# %%
correct_key = 35 #0x23
subkey = 11
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 35 #0x23
subkey = 11
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([10500, 10850])
plt.show()

# %% [markdown]
# ### Byte 12

# %%
correct_key = 152 #0x98
subkey = 12
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 152 #0x98
subkey = 12
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([6050, 6300])
plt.show()

# %% [markdown]
# ### Byte 13

# %%
correct_key = 84 #0x54
subkey = 13
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 84 #0x54
subkey = 13
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([7300, 7600])
plt.show()

# %% [markdown]
# ### Byte 14

# %%
correct_key = 18 #0x12
subkey = 14
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 18 #0x12
subkey = 14
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([8550, 8900])
plt.show()

# %% [markdown]
# ### Byte 15

# %%
correct_key = 18 #0x12
subkey = 15
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.show()

# %%
correct_key = 18 #0x12
subkey = 15
plt.figure()
for guess in range(0, 256):
    if (guess == correct_key):
        plt.plot(full_diffs_list[subkey][guess],color="red",linewidth=1.5, linestyle='-',zorder=255)
    else:
        plt.plot(full_diffs_list[subkey][guess],color="grey")
plt.xlim([9650, 10000])
plt.show()

# %% [markdown]
# ### All Bytes

# %%
plt.figure()
for subkey in range(0, 16):
    plt.plot(full_diffs_list[subkey][known_key[subkey]])
plt.show()
