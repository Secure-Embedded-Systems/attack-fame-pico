# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # CPA Method 1 (Faster) - Byte8 Most Difficult to Recover

# %%
x = [0,1000,2000,3000,4000,5000,10000,15000,20000,25000,30000,50000,60000,70000]
y = [0,2,7,10,13,15,14,14,15,15,15,15,16,16]
plt.plot(x, y)
plt.grid()
plt.xlabel('Number of Traces')
plt.ylabel('Correct Key Bytes')
plt.title('CPA Number of traces vs. correctly guessed key bytes')
# Out:
# Text(0.5, 1.0, 'CPA Number of traces vs. correctly guessed key bytes')

# %% [markdown]
# ##### For 50000 traces - Subkey  8 - most likely BE (actual BB) Top 5 guesses:
# * BE - Diff = 0.099124
# * B4 - Diff = 0.096699
# * B2 - Diff = 0.094572
# * BB - Diff = 0.094040
# * B0 - Diff = 0.090611

# %% [markdown]
# ##### For 60000 traces - Subkey  8 - most likely BB (actual BB) Top 5 guesses:
# * BB - Diff = 0.097332
# * B2 - Diff = 0.096136
# * BE - Diff = 0.095541
# * B4 - Diff = 0.094597
# * B6 - Diff = 0.089317

# %% [markdown]
# ##### For 70000 traces - Subkey  8 - most likely BB (actual BB) Top 5 guesses:
# * BB - Diff = 0.098027
# * BE - Diff = 0.093608
# * B2 - Diff = 0.093128
# * B4 - Diff = 0.092515
# * B0 - Diff = 0.090088

# %% [markdown]
# # CPA Method 2 - Byte8 Most Difficult to Recover - Inside the Top 5 List

# %%
x = [0,1000,2000,3000,4000,5000,10000,15000,20000,25000,30000,50000,60000,70000]
y = [0,2,7,10,13,15,14,14,15,15,15,15,16,16]
plt.plot(x, y)
plt.grid()
plt.xlabel('Number of Traces')
plt.ylabel('Correct Key Bytes')
plt.title('CPA Number of traces vs. correctly guessed key bytes')
# Out:
# Text(0.5, 1.0, 'CPA Number of traces vs. correctly guessed key bytes')

# %% [markdown]
# # DPA - Byte0 Most Difficult to Recover - Not Inside the Top 5 List

# %%
x = [0,2500,5000,7500,10000,12500,15000,17500,20000,30000,40000,50000,60000,70000,80000,90000,100000,110000,120000,130000,140000,150000]
y = [0,0,3,4,7,9,11,12,11,14,13,13,15,15,15,15,15,15,15,15,15,15]
plt.plot(x, y)
plt.grid()
plt.xlabel('Number of Traces')
plt.ylabel('Correct Key Bytes')
plt.title('DPA Number of traces vs. correctly guessed key bytes')
# Out:
# Text(0.5, 1.0, 'DPA Number of traces vs. correctly guessed key bytes')

# %% [markdown]
# ##### For 50000 traces - Subkey  0 - most likely 57 (actual 54) Top 5 guesses: Attack failed (not in the top 5 list)
# * 57 - Diff = 0.010097
# * DC - Diff = 0.010005
# * 5F - Diff = 0.009920
# * 53 - Diff = 0.009902
# * D8 - Diff = 0.009686

# %% [markdown]
# ##### For 100000 traces - Subkey  0 - most likely 51 (actual 54) Top 5 guesses: Attack failed (in the top 5 list)
# * 51 - Diff = 0.009760
# * 54 - Diff = 0.009612
# * 55 - Diff = 0.009595
# * 5D - Diff = 0.009588
# * 5B - Diff = 0.009556
