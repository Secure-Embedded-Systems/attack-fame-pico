# %%
import trsfile

with trsfile.open('../Downloads/RO_RandFre_off + Tvla T-test.trs', 'r') as traces:
    for header, value in traces.get_headers().items():
        print(header, '=', value)
    print()
    trace_list = []
    for i, trace in enumerate(traces[0:2000]):
        trace_list.append(trace.samples)
        print(trace_sample)
# Out:
# Header.NUMBER_TRACES = 1000
# Header.NUMBER_SAMPLES = 6500
# Header.SAMPLE_CODING = SampleCoding.FLOAT
# Header.TITLE_SPACE = 128
# Header.TRACE_TITLE = trace
# Header.DESCRIPTION =
# ----------- T-TEST MODULE PARAMETERS SECTION DO NOT MODIFY -----------
# Trace set contains the following TVLA sets: Random, Fixed
# Fixed vs Random
# ----------- END T-TEST MODULE PARAMETERS SECTION -----------
#
#
# ----------- T-TEST MODULE PARAMETERS SECTION DO NOT MODIFY -----------
# Trace set contains the following TVLA sets: Random, Fixed
# Fixed vs Random
# ----------- END T-TEST MODULE PARAMETERS SECTION -----------
#
# Header.LABEL_X = s
# Header.SCALE_X = 2.000000026702864e-10
# Header.NUMBER_VIEW = 2
# Header.TRACE_OVERLAP = True
# Header.GO_LAST_TRACE = True
# Header.ACQUISITION_RANGE_OF_SCOPE = 0.5
# Header.ACQUISITION_COUPLING_OF_SCOPE = 1
# Header.ACQUISITION_INPUT_IMPEDANCE = 1000000.0
# Header.ACQUISITION_DEVICE_ID = b'44de458c-a1ac-43f8-9701-b5c4b2cf00d1'
# ...

# %%
trace_sample
# Out:
# array([4.5, 4.5, 4.5, ..., 4.5, 4.5, 4.5], dtype=float32)

# %%
trace_list[2]
# Out:
# array([0.10548266, 0.06347269, 0.24575323, ..., 0.27881193, 0.47868985,
#        0.56535447], dtype=float32)

# %%
import numpy as np
import matplotlib.pylab as plt
plt.plot(trace_list[0])
plt.plot(trace_list[1])
plt.title('T-test Plot')
plt.savefig('T-test.jpg',dpi=300)
