# %% [markdown]
# # Import traces

# %%
import glob
import os

list_of_files = glob.glob('measured_traces/traces*.bin') 
latest_file = max(list_of_files, key=os.path.getctime)
print('latest file is:',latest_file)

list = os.listdir('measured_traces') 
number_files = len(list)
print('total file number is:',number_files)
# Out:
# latest file is: measured_traces/traces5534.bin
# total file number is: 5535

# %%
import glob
trace_enc = []
path = "measured_traces/traces*.bin"
for filename in sorted(glob.glob(path, recursive=True),key = lambda x: x[-9:]):
    break
    #print(filename)
    
    #one_trace = np.array(np.array_split(np.fromfile(filename, dtype=np.float64), 24400))
    #trace_enc.append(one_trace)
    #break

# %%
import matplotlib.pylab as plt
plt.plot(one_trace)
